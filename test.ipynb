# %%
image_b64 = "..."

# %%
from utils import bs64_to_pil, pil_to_bs64

# %%
bs64_to_pil(image_b64)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x302>

# %% [markdown]
# ## Remove bg
# - not queue

# %%
import requests
import json

url = 'http://localhost:8000/utils/remove_bg/'  # Flask 애플리케이션의 URL로 변경
headers = {'Content-Type': 'application/json'}  # JSON 형식의 데이터를 보낼 것임

remove_bg_body = {"image_b64":image_b64, "post_process":True}
# JSON 데이터를 문자열로 변환하여 전송
response = requests.post(url, headers=headers, data=json.dumps({"body":remove_bg_body}))

# 응답 확인
print('Status Code:', response.status_code)
print('Response Content:', response.text)

mask_b64 = json.loads(json.loads(response.text)["body"])["image_b64"].split("base64,")[1]
# Out:
# Status Code: 200
# Response Content: {
#   "body": "{\"type\": \"remove_bg\", \"image_b64\": \"data:application/octet-stream;base64,...\"}",
#   "statusCode": 200
# }

# %% [markdown]
# ## Mask post process
# - not queue

# %%
import requests
import json

url = 'http://localhost:8000/utils/remove_bg/postprocess/'  # Flask 애플리케이션의 URL로 변경
headers = {'Content-Type': 'application/json'}  # JSON 형식의 데이터를 보낼 것임

mask_post_process_body = {"mask_b64":mask_b64}
# JSON 데이터를 문자열로 변환하여 전송
response = requests.post(url, headers=headers, data=json.dumps({"body":mask_post_process_body}))

# 응답 확인
print('Status Code:', response.status_code)
print('Response Content:', response.text)
# Out:
# Status Code: 200
# Response Content: {
#   "body": "{\"type\": \"mask_post_process\", \"image_b64\": \"data:application/octet-stream;base64,...\"}",
#   "statusCode": 200
# }

# %% [markdown]
# ## Recommend colors
# - not queue

# %%
import requests
import json

url = 'http://localhost:8000/utils/recommend_colors/'  # Flask 애플리케이션의 URL로 변경
headers = {'Content-Type': 'application/json'}  # JSON 형식의 데이터를 보낼 것임

recommend_colors_body = {"image_b64":image_b64, "mask_b64": mask_b64}
# JSON 데이터를 문자열로 변환하여 전송
response = requests.post(url, headers=headers, data=json.dumps({"body":recommend_colors_body}))

# 응답 확인
print('Status Code:', response.status_code)
print('Response Content:', response.text)
# Out:
# Status Code: 200
# Response Content: {
#   "body": "{\"type\": \"recommend_colors\", \"similar_colors\": [[255, 255, 174], [250, 249, 181], [198, 126, 35], [159, 105, 46]], \"similar_weights\": [0.44207057158695984, 0.2981944518543231, 0.14443057250332642, 0.10193401730298195], \"creative_colors\": [[16, 12, 8], [244, 240, 236], [85, 85, 85], [139, 133, 137]], \"creative_weights\": [0.25092467199914137, 0.2503930045751534, 0.24950164882480103, 0.2491806746009042]}",
#   "statusCode": 200
# }

# %% [markdown]
# ## Color enhancement
# - no queue

# %%
import requests
import json

url = 'http://localhost:8000/utils/color_enhancement/'  # Flask 애플리케이션의 URL로 변경
headers = {'Content-Type': 'application/json'}  # JSON 형식의 데이터를 보낼 것임

color_enhancement_body = {"image_b64":image_b64, "gamma":0.75, "factor":1.2}
# JSON 데이터를 문자열로 변환하여 전송
response = requests.post(url, headers=headers, data=json.dumps({"body":color_enhancement_body}))

# 응답 확인
print('Status Code:', response.status_code)
print('Response Content:', response.text)
# Out:
# Status Code: 200
# Response Content: {
#   "body": "{\"type\": \"color_enhancement\", \"image_b64\": \"data:application/octet-stream;base64,...\"}",
#   "statusCode": 200
# }

# %% [markdown]
# ## BLIP
# - no queue

# %%
import requests
import json

url = 'http://localhost:8000/utils/text_to_image/blip/'  # Flask 애플리케이션의 URL로 변경
headers = {'Content-Type': 'application/json'}  # JSON 형식의 데이터를 보낼 것임

blip_body = {"image_b64":image_b64}
# JSON 데이터를 문자열로 변환하여 전송
response = requests.post(url, headers=headers, data=json.dumps({"body":blip_body}))

# 응답 확인
print('Status Code:', response.status_code)
print('Response Content:', response.text)
# Out:
# Status Code: 200
# Response Content: {
#   "body": "{\"type\": \"blip\", \"caption\": \"two bottles are labeled with asian characters on them\"}",
#   "statusCode": 200
# }

# %% [markdown]
# ## CLIP
# - no queue

# %%
import requests
import json

url = 'http://localhost:8000/utils/text_to_image/clip/'  # Flask 애플리케이션의 URL로 변경
headers = {'Content-Type': 'application/json'}  # JSON 형식의 데이터를 보낼 것임

clip_body = {"image_b64":image_b64}
# JSON 데이터를 문자열로 변환하여 전송
response = requests.post(url, headers=headers, data=json.dumps({"body":clip_body}))

# 응답 확인
print('Status Code:', response.status_code)
print('Response Content:', response.text)
# Out:
# Status Code: 200
# Response Content: {
#   "body": "{\"type\": \"clip\", \"caption\": \"two plastic milk bottles with a brown cap, honey and bee hive, top milk brands, product label, honey wind, inspired by Byeon Sang-byeok, flowing milk, round bottle, bee, (bee), sea of milk, product advertisement, packaging award, kwak ji young, korean writing, :6, jar of honey, productphoto, milkman\"}",
#   "statusCode": 200
# }

# %% [markdown]
# ## Super resolution
# - queue

# %%
import requests
import json

url = 'http://localhost:8000/utils/super_resolution/'  # Flask 애플리케이션의 URL로 변경
headers = {'Content-Type': 'application/json'}  # JSON 형식의 데이터를 보낼 것임

super_resolution_body = {"image_b64":image_b64, "request_id":0}
# JSON 데이터를 문자열로 변환하여 전송
response = requests.post(url, headers=headers, data=json.dumps({"body":super_resolution_body}))

# 응답 확인
print('Status Code:', response.status_code)
print('Response Content:', response.text)
# Out:
# Status Code: 200
# Response Content: {
#   "body": "{\"state\": \"queued\", \"type\": \"super_resolution\", \"request_qsize\": 1}",
#   "statusCode": 200
# }

# %% [markdown]
# ## Outpaint
# - queue

# %%
import requests
import json

url = 'http://localhost:8000/diffusion/outpaint/'  # Flask 애플리케이션의 URL로 변경
headers = {'Content-Type': 'application/json'}  # JSON 형식의 데이터를 보낼 것임

outpaint_body = {"image_b64":image_b64, "mask_b64":mask_b64, "request_id":1}
# JSON 데이터를 문자열로 변환하여 전송
response = requests.post(url, headers=headers, data=json.dumps({"body":outpaint_body}))

# 응답 확인
print('Status Code:', response.status_code)
print('Response Content:', response.text)
# Out:
# Status Code: 200
# Response Content: {
#   "body": "{\"state\": \"queued\", \"type\": \"outpaint\", \"request_qsize\": 1}",
#   "statusCode": 200
# }

# %% [markdown]
# ## Composition
# - queue

# %%
import requests
import json

url = 'http://localhost:8000/diffusion/composition/'  # Flask 애플리케이션의 URL로 변경
headers = {'Content-Type': 'application/json'}  # JSON 형식의 데이터를 보낼 것임

composition_body = {"image_b64":image_b64, "mask_b64":mask_b64, "request_id":2}
# JSON 데이터를 문자열로 변환하여 전송
response = requests.post(url, headers=headers, data=json.dumps({"body":composition_body}))

# 응답 확인
print('Status Code:', response.status_code)
print('Response Content:', response.text)
# Out:
# Status Code: 200
# Response Content: {
#   "body": "{\"state\": \"queued\", \"type\": \"composition\", \"request_qsize\": 1}",
#   "statusCode": 200
# }

# %% [markdown]
# ## Augmentation base style
# - queue

# %%
import requests
import json

url = 'http://localhost:8000/diffusion/augmentation/style/'  # Flask 애플리케이션의 URL로 변경
headers = {'Content-Type': 'application/json'}  # JSON 형식의 데이터를 보낼 것임

augmentation_style_body = {"image_b64_base":image_b64, "image_b64_style":image_b64, "request_id":3}
# JSON 데이터를 문자열로 변환하여 전송
response = requests.post(url, headers=headers, data=json.dumps({"body":augmentation_style_body}))

# 응답 확인
print('Status Code:', response.status_code)
print('Response Content:', response.text)
# Out:
# Status Code: 200
# Response Content: {
#   "body": "{\"state\": \"queued\", \"type\": \"augmentation_style\", \"request_qsize\": 1}",
#   "statusCode": 200
# }

# %% [markdown]
# ## Augmentation base text
# - queue

# %%
import requests
import json

url = 'http://localhost:8000/diffusion/augmentation/text/'  # Flask 애플리케이션의 URL로 변경
headers = {'Content-Type': 'application/json'}  # JSON 형식의 데이터를 보낼 것임

augmentation_text_body = {"image_b64":image_b64, "color":"red", "concept":"marble", "request_id":4}
# JSON 데이터를 문자열로 변환하여 전송
response = requests.post(url, headers=headers, data=json.dumps({"body":augmentation_text_body}))

# 응답 확인
print('Status Code:', response.status_code)
print('Response Content:', response.text)
# Out:
# Status Code: 200
# Response Content: {
#   "body": "{\"state\": \"queued\", \"type\": \"augmentation_text\", \"request_qsize\": 1}",
#   "statusCode": 200
# }

# %% [markdown]
# ## Get result
# - get from queue

# %%
url = 'http://localhost:8000/get_result/'
headers = {'Content-Type': 'application/json'}  # JSON 형식의 데이터를 보낼 것임

get_result_body = {"request_id":4}
response = requests.post(url, headers=headers, data=json.dumps({"body":get_result_body}))
print('Status Code:', response.status_code)
print('Response Content:', response.text)
# Out:
# Status Code: 200
# Response Content: {
#   "body": "{\"image_b64_list\": [\"data:application/octet-stream;base64,...\"], \"request_id\": 4}",
#   "statusCode": 200
# }

# %%
bs64_to_pil(json.loads(json.loads(response.text)["body"])["image_b64_list"][0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x618>
